# %% [markdown]
# # Introducción a los números complejos
#
# Un **número complejo** es un número de la forma:
#
# $$ z = a + bi $$
#
#
# donde:
#
# - $a$ es la **parte real**
# - $b$ es la **parte imaginaria**
# - $i$ es la unidad imaginaria, tal que:
#
# $$ i^2 = -1 $$
#
#
# ## Ejemplo
#
# $$ z = 3 + 4i $$
#
# - Parte real: 3
# - Parte imaginaria: 4
#
# ## Números complejos en Python
#
# En Python, los números complejos se representan usando `j` en lugar de `i`:

# %%
z = 3 + 4j
print(z)

# %% [markdown]
# También puedes acceder a sus partes:

# %%
print(z.real)  # parte real
print(z.imag)  # parte imaginaria

# %% [markdown]
# ## Forma polar
#
# Un número complejo también puede representarse como:
#
# $$ z = r(\cos \theta + i \sin \theta) $$
#
# donde:
#
# - $r$ es el **módulo** (distancia al origen)
# - $\theta$ es el **argumento** (ángulo)
#
# El módulo se calcula como:
#
# $$ r = \sqrt{a^2 + b^2} $$

# %% [markdown]
# ## Librería cmath en Python
#
# La librería cmath está diseñada para trabajar con números complejos (a diferencia de math, que es solo para números reales).A continuacion realizaremos calculos con la libreria cmath.

# %%
import cmath

# %% [markdown]
# Módulo (valor absoluto)

# %%
z = 3 + 4j
print(abs(z))

# %% [markdown]
# Argumento

# %%
print(cmath.phase(z))

# %% [markdown]
# Conversión a forma polar

# %%
r, theta = cmath.polar(z)
print(r, theta)

# %% [markdown]
# Conversión de forma polar a cartesiana

# %%
z = cmath.rect(r, theta)
print(z)

# %% [markdown]
# Raíz cuadrada de números negativos

# %%
print(cmath.sqrt(-1))  # resultado: 1j

# %% [markdown]
# Funciones trigonométricas

# %%
z = 1 + 1j

print(cmath.sin(z))
print(cmath.cos(z))

# %% [markdown]
# Exponenciales y logaritmos

# %%
print(cmath.exp(1j))   # e^(i)
print(cmath.log(1 + 1j))

# %% [markdown]
# ## Ejemplo: Resolver $x^2 + 1 = 0$ usando `cmath`
#
# Queremos resolver la ecuación:
#
#
# $ x^2 + 1 = 0 $
#
#
# Sabemos que:
#
# $ x^2 = -1 $
#
# Por lo tanto:
#
#
# $ x = \pm \sqrt{-1} $
#
# En números complejos:
#
#
# $ x = \pm i $
#
# A continuación resolvamos la ecuación $ x^2 + 1 = 0 $
# usando Python.

# %%
# resolver x^2 + 1 = 0
# x = ± sqrt(-1)

raiz1 = cmath.sqrt(-1)
raiz2 = -cmath.sqrt(-1)

print("Solución 1:", raiz1)
print("Solución 2:", raiz2)

# %% [markdown]
# ## Ejercicios
#
# 1. Crear y analizar un número complejo
#
# Crea un número complejo z=5+2j y:
#
# * Imprime su parte real
# * Imprime su parte imaginaria
# * Calcula su módulo usando abs()

# %% [markdown]
# 2. Forma polar
#
# Usa cmath.polar() para convertir el número complejo z=1+1j a forma polar.
#
# * Imprime el módulo
# * Imprime el ángulo

# %% [markdown]
# 3. De forma polar a cartesiana
#
# Dado un módulo $r=2$ y un ángulo $\theta = \frac{\pi}{4}$
#
# * Usa cmath.rect() para obtener el número complejo correspondiente
# * Imprime el resultado

# %% [markdown]
# 4. Operaciones con funciones complejas
#
# Para el número complejo z=2+3j:
#
# * Calcula sin(z)
# * Calcula cos(z)
# * Calcula $e^{z}$ usando cmath.exp()

# %% [markdown]
# 5. Resolver una ecuación cuadrática
#
# Resuelve la ecuación:
#
# $$ x^2 + 4 = 0 $$
#
# Usando cmath.
#
# * Calcula ambas soluciones
# * Imprime los resultados
